# %% [markdown]
# # 0. 준비과정

# %% [markdown]
# ## 0.1. 패키지 및 모듈 불러오기

# %%
from sklearn.preprocessing import StandardScaler,LabelEncoder
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import  linear_model
from sklearn import  preprocessing
from pandas.plotting import scatter_matrix
import tensorflow as tf
import seaborn as sns

# %% [markdown]
# ## 0.2. 데이터 불러오기

# %%
#데이터 프레임 정의
all_df =pd.read_csv('./house_price.csv', header = 'infer')
all_df.head()
# Out:
#    BATHROOMS  NUM_UNITS  ROOMS  BEDROOMS  REMODEL_YEAR  STORIES    PRICE  \
# 0          4          2      8         4          1988     3.00  1095000
# 1          4          2      9         5          2009     2.00  2100000
# 2          4          2      8         5          2003     2.00  1602000
# 3          4          2      8         4          2011     2.25  1050000
# 4          4          2      7         3          2008     3.75  1430000
#
#    BUILDING_AREA  CONDITION  KITCHENS  FIREPLACES  LAND_AREA
# 0           2522       Good         2           5      10000
# 1           2522  Very Good         2           4       1523
# 2           2484       Good         2           3        882
# 3           2401    Average         2           1       3938
# 4           1488  Very Good         2           1       5000

# %% [markdown]
# # 1. 데이터 전처리

# %% [markdown]
# ## 1.0. 데이터 살펴보기

# %%
# 데이터 살펴보기
all_df.describe()
# Out:
#           BATHROOMS     NUM_UNITS         ROOMS      BEDROOMS  REMODEL_YEAR  \
# count  33149.000000  33149.000000  33149.000000  33149.000000  33149.000000
# mean       3.059459      1.239404      7.577121      3.527588   2004.255634
# std        1.266186      0.612707      2.330588      1.168190     16.656236
# min        0.000000      0.000000      0.000000      0.000000     20.000000
# 25%        2.000000      1.000000      6.000000      3.000000   2002.000000
# 50%        3.000000      1.000000      7.000000      3.000000   2008.000000
# 75%        4.000000      1.000000      9.000000      4.000000   2013.000000
# max       13.000000      6.000000     31.000000     20.000000   2019.000000
#
#             STORIES         PRICE  BUILDING_AREA      KITCHENS    FIREPLACES  \
# count  33149.000000  3.314900e+04   33149.000000  33149.000000  33149.000000
# mean       2.157705  6.854647e+05    1785.509638      1.282874      0.759540
# std        5.199738  6.446433e+05     860.463942      0.672300      0.986825
# min        0.000000  1.377000e+03     407.000000      0.000000      0.000000
# 25%        2.000000  3.250000e+05    1240.000000      1.000000      0.000000
# 50%        2.000000  5.660000e+05    1560.000000      1.000000      1.000000
# 75%        2.000000  8.425000e+05    2087.000000      1.000000      1.000000
# max      826.000000  2.396029e+07   15902.000000     44.000000     13.000000
#
#            LAND_AREA
# count   33149.000000
# mean     3158.558629
# std      3289.642242
# min       216.000000
# 25%      1471.000000
# 50%      2090.000000
# 75%      3987.000000
# max    155905.000000

# %%
# 데이터형 살펴보기
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33149 entries, 0 to 33148
# Data columns (total 12 columns):
# BATHROOMS        33149 non-null int64
# NUM_UNITS        33149 non-null int64
# ROOMS            33149 non-null int64
# BEDROOMS         33149 non-null int64
# REMODEL_YEAR     33149 non-null int64
# STORIES          33149 non-null float64
# PRICE            33149 non-null int64
# BUILDING_AREA    33149 non-null int64
# CONDITION        33149 non-null object
# KITCHENS         33149 non-null int64
# FIREPLACES       33149 non-null int64
# LAND_AREA        33149 non-null int64
# dtypes: float64(1), int64(10), object(1)
# memory usage: 3.0+ MB

# %% [markdown]
# ## 1.1. 컬럼별 결측치 파악

# %%
# 컬럼별 결측치 파악
all_df.isnull().sum().sort_values(ascending=False).head(12)
# Out:
# LAND_AREA        0
# FIREPLACES       0
# KITCHENS         0
# CONDITION        0
# BUILDING_AREA    0
# PRICE            0
# STORIES          0
# REMODEL_YEAR     0
# BEDROOMS         0
# ROOMS            0
# NUM_UNITS        0
# BATHROOMS        0
# dtype: int64

# %% [markdown]
# ## 1.2. 이상값처리

# %% [markdown]
# ### 1.2.1. REMODEL_YEAR

# %%
#산포도 시각화
plt.scatter(all_df['PRICE'], all_df['REMODEL_YEAR']);

# %%
# 20년도 리모델링 된 이상값 제거
all_df = all_df.drop(all_df[all_df['REMODEL_YEAR'] == 20].index)

# %% [markdown]
# ### 1.2.2. LAND_AREA

# %%
#산포도 시각화
plt.scatter(all_df['PRICE'], all_df['LAND_AREA']);

# %%
all_df = all_df.drop(all_df[all_df['LAND_AREA'] >= 14966].index)

# %% [markdown]
# ### 1.2.3. BUILDING_AREA

# %%
#산포도 시각화
plt.scatter(all_df['PRICE'], all_df['BUILDING_AREA']);

# %% [markdown]
# ### 1.2.4. NUM_UNITS

# %%
var = 'NUM_UNITS'
data = pd.concat([all_df['PRICE'], all_df[var]], axis=1)
f, ax = plt.subplots(figsize=(20, 5))
fig = sns.boxplot(x=var, y="PRICE", data=data)
fig.axis(ymin=0, ymax=5000000);
xt = plt.xticks(rotation=45)

# %% [markdown]
# ### 1.2.5. BATHROOMS

# %%
var = 'BATHROOMS'
data = pd.concat([all_df['PRICE'], all_df[var]], axis=1)
f, ax = plt.subplots(figsize=(20, 5))
fig = sns.boxplot(x=var, y="PRICE", data=data)
fig.axis(ymin=100000, ymax=10000000);
xt = plt.xticks(rotation=45)

# %% [markdown]
# ### 1.2.6. ROOMS

# %%
var = 'ROOMS'
data = pd.concat([all_df['PRICE'], all_df[var]], axis=1)
f, ax = plt.subplots(figsize=(20, 5))
fig = sns.boxplot(x=var, y="PRICE", data=data)
fig.axis(ymin=0, ymax=10000000);
xt = plt.xticks(rotation=45)

# %% [markdown]
# ### 1.2.7. BEDROOMS

# %%
var = 'BEDROOMS'
data = pd.concat([all_df['PRICE'], all_df[var]], axis=1)
f, ax = plt.subplots(figsize=(20, 5))
fig = sns.boxplot(x=var, y="PRICE", data=data)
fig.axis(ymin=0, ymax=10000000);
xt = plt.xticks(rotation=45)

# %% [markdown]
# ### 1.2.8. STORIES

# %%
var = 'STORIES'
data = pd.concat([all_df['PRICE'], all_df[var]], axis=1)
f, ax = plt.subplots(figsize=(20, 5))
fig = sns.boxplot(x=var, y="PRICE", data=data)
fig.axis(ymin=0, ymax=10000000);
xt = plt.xticks(rotation=45)

# %%
all_df = all_df.drop(all_df[all_df['STORIES'] > 200].index)

# %% [markdown]
# ### 1.2.9. CONDITION

# %%
var = 'CONDITION'
data = pd.concat([all_df['PRICE'], all_df[var]], axis=1)
f, ax = plt.subplots(figsize=(20, 5))
fig = sns.boxplot(x=var, y="PRICE", data=data)
fig.axis(ymin=0, ymax=10000000);
xt = plt.xticks(rotation=45)

# %% [markdown]
# ### 1.2.10. KITCHENS

# %%
var = 'KITCHENS'
data = pd.concat([all_df['PRICE'], all_df[var]], axis=1)
f, ax = plt.subplots(figsize=(20, 5))
fig = sns.boxplot(x=var, y="PRICE", data=data)
fig.axis(ymin=0, ymax=5000000);
xt = plt.xticks(rotation=45)

# %%
all_df = all_df.drop(all_df[all_df['KITCHENS'] == 44].index)

# %% [markdown]
# ### 1.2.11. FIREPLACES

# %%
var = 'FIREPLACES'
data = pd.concat([all_df['PRICE'], all_df[var]], axis=1)
f, ax = plt.subplots(figsize=(20, 5))
fig = sns.boxplot(x=var, y="PRICE", data=data)
fig.axis(ymin=0, ymax=10000000);
xt = plt.xticks(rotation=45)

# %% [markdown]
# ### 1.2.11. FIREPLACES

# %%
#histogram
sns.distplot(all_df['PRICE']);

# %%
all_df = all_df.drop(all_df[all_df['PRICE'] > 4050000].index)

# %% [markdown]
# ## 1.3. 피쳐 간 상관관계 파악

# %%
#scatterplot
sns.set()
cols = ['BATHROOMS', 'NUM_UNITS', 'ROOMS', 'BEDROOMS', 'REMODEL_YEAR',
       'STORIES', 'PRICE', 'BUILDING_AREA', 'CONDITION', 'KITCHENS',
       'FIREPLACES', 'LAND_AREA']
sns.pairplot(all_df[cols], size = 2.5)
plt.show();

# %%
#saleprice correlation matrix
k = 10 #number of variables for heatmap
cols = corrmat.nlargest(k, 'PRICE')['PRICE'].index
cm = np.corrcoef(all_df[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
corrmat = all_df.corr() #Correlation_Matrix
cols = corrmat.nlargest(15, 'PRICE')['PRICE']
print(cols)
# Out:
# PRICE            1.000000
# BUILDING_AREA    0.591749
# BATHROOMS        0.567441
# FIREPLACES       0.516311
# BEDROOMS         0.376762
# ROOMS            0.347319
# REMODEL_YEAR     0.080036
# KITCHENS         0.042938
# LAND_AREA        0.000994
# NUM_UNITS       -0.002471
# STORIES         -0.005453
# Name: PRICE, dtype: float64

# %% [markdown]
# ## 2.4.  형변환 및 피쳐삭제

# %%
# 상관관계가 미비하거나 중복되는 피쳐인 경우 Drop
del all_df['NUM_UNITS']
del all_df['ROOMS']
del all_df['LAND_AREA']
del all_df['STORIES']

# %%
#순서가 있는 카테고리형 데이터 'CONDITION'을 숫자로 변환
label = LabelEncoder()
   
all_df['CONDITION'] = label.fit_transform(all_df['CONDITION'])

# %% [markdown]
# # 2. 데이터 학습 및 실험

# %% [markdown]
# ## 2.1. Train, Test Set 분할

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler ,normalize
from sklearn import preprocessing

# %%
# Y 값을 list화 한 뒤 train_y에 할당
full_y= all_df['PRICE'].values

# Y값 제거
del all_df['PRICE']

# DataFrame을 스케일링 및 list화 한 뒤 full_x에 할당
min_max_scaler = preprocessing.MinMaxScaler()
full_x = min_max_scaler.fit_transform(all_df)

# DataFrame을 list화 한 뒤 train_x에 할당
# full_x =  all_df.values

# %%
# 크기 확인
full_x.shape, full_y.shape
# Out:
# ((32701, 7), (32701,))

# %%
#정확도 측정 셋 분할
from sklearn.model_selection import train_test_split

X_training, X_valid, y_training, y_valid = train_test_split(full_x, full_y, test_size=0.2, random_state=0)

# %% [markdown]
# ## 2.2. 모델 학습

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.cross_validation import cross_val_score, KFold

# %% [markdown]
# ### 2.2.1. LinearRegression

# %%
linreg = LinearRegression()
parameters_lin = {"fit_intercept" : [True, False], "normalize" : [True, False], "copy_X" : [True, False]}
grid_linreg = GridSearchCV(linreg, parameters_lin, verbose=1 , scoring = "r2")
grid_linreg.fit(X_training, y_training)

print("Best LinReg Model: " + str(grid_linreg.best_estimator_))
print("Best Score: " + str(grid_linreg.best_score_))
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# Best LinReg Model: LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=True)
# Best Score: 0.5138309486521887
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:    0.2s finished

# %%
linreg = grid_linreg.best_estimator_
linreg.fit(X_training, y_training)
lin_pred = linreg.predict(X_valid)
r2_lin = r2_score(y_valid, lin_pred)
rmse_lin = np.sqrt(mean_squared_error(y_valid, lin_pred))
print("R^2 Score: " + str(r2_lin))
print("RMSE Score: " + str(rmse_lin))
# Out:
# R^2 Score: 0.5137569100865864
# RMSE Score: 339948.4486631182

# %%
scores_lin = cross_val_score(linreg, X_training, y_training, cv=10, scoring="r2")
print("Cross Validation Score: " + str(np.mean(scores_lin)))
# Out:
# Cross Validation Score: 0.5133932499305278

# %% [markdown]
# ### 2.2.2. Lasso

# %%
lasso = Lasso()
parameters_lasso = {"fit_intercept" : [True, False], "normalize" : [True, False], "precompute" : [True, False], "copy_X" : [True, False]}
grid_lasso = GridSearchCV(lasso, parameters_lasso, verbose=1, scoring="r2")
grid_lasso.fit(X_training, y_training)

print("Best Lasso Model: " + str(grid_lasso.best_estimator_))
print("Best Score: " + str(grid_lasso.best_score_))
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best Lasso Model: Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)
# Best Score: 0.5138309635280339
# [Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed:    2.7s finished

# %%
lasso = grid_lasso.best_estimator_
lasso.fit(X_training, y_training)
lasso_pred = lasso.predict(X_valid)
r2_lasso = r2_score(y_valid, lasso_pred)
rmse_lasso = np.sqrt(mean_squared_error(y_valid, lasso_pred))
print("R^2 Score: " + str(r2_lasso))
print("RMSE Score: " + str(rmse_lasso))
# Out:
# R^2 Score: 0.5137612038707294
# RMSE Score: 339946.94769733475

# %%
scores_lasso = cross_val_score(lasso, X_training, y_training, cv=10, scoring="r2")
print("Cross Validation Score: " + str(np.mean(scores_lasso)))
# Out:
# Cross Validation Score: 0.5133932872356279

# %% [markdown]
# ### 2.2.3. Ridge

# %%
ridge = Ridge()
parameters_ridge = {"fit_intercept" : [True, False], "normalize" : [True, False], "copy_X" : [True, False], "solver" : ["auto"]}
grid_ridge = GridSearchCV(ridge, parameters_ridge, verbose=1, scoring="r2")
grid_ridge.fit(X_training, y_training)

print("Best Ridge Model: " + str(grid_ridge.best_estimator_))
print("Best Score: " + str(grid_ridge.best_score_))
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# Best Ridge Model: Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)
# Best Score: 0.5138212485405442
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:    0.1s finished

# %%
ridge = grid_ridge.best_estimator_
ridge.fit(X_training, y_training)
ridge_pred = ridge.predict(X_valid)
r2_ridge = r2_score(y_valid, ridge_pred)
rmse_ridge = np.sqrt(mean_squared_error(y_valid, ridge_pred))
print("R^2 Score: " + str(r2_ridge))
print("RMSE Score: " + str(rmse_ridge))
# Out:
# R^2 Score: 0.5138820274091129
# RMSE Score: 339904.7090429114

# %%
scores_ridge = cross_val_score(ridge, X_training, y_training, cv=10, scoring="r2")
print("Cross Validation Score: " + str(np.mean(scores_ridge)))
# Out:
# Cross Validation Score: 0.5133841566401383

# %% [markdown]
# ### 2.2.4. DecisionTree

# %%
# dtr = DecisionTreeRegressor()
# parameters_dtr = {"criterion" : ["mse", "friedman_mse", "mae"], "splitter" : ["best", "random"], "min_samples_split" : [2, 3, 5, 10], 
#                   "max_features" : ["auto", "log2"]}
# grid_dtr = GridSearchCV(dtr, parameters_dtr, verbose=1, scoring="r2")
# grid_dtr.fit(X_training, y_training)

# print("Best DecisionTreeRegressor Model: " + str(grid_dtr.best_estimator_))
# print("Best Score: " + str(grid_dtr.best_score_))

# %%
# dtr = grid_dtr.best_estimator_
# dtr.fit(X_training, y_training)
# dtr_pred = dtr.predict(X_valid)
# r2_dtr = r2_score(y_valid, dtr_pred)
# rmse_dtr = np.sqrt(mean_squared_error(y_valid, dtr_pred))
# print("R^2 Score: " + str(r2_dtr))
# print("RMSE Score: " + str(rmse_dtr))

# %%
# scores_dtr = cross_val_score(dtr, X_training, y_training, cv=10, scoring="r2")
# print("Cross Validation Score: " + str(np.mean(scores_dtr)))

# %% [markdown]
# ### 2.2.5. RandomForest

# %%
# rf = RandomForestRegressor()
# paremeters_rf = {"n_estimators" : [5, 10, 15, 20], "criterion" : ["mse" , "mae"], "min_samples_split" : [2, 3, 5, 10], 
#                  "max_features" : ["auto", "log2"]}
# grid_rf = GridSearchCV(rf, paremeters_rf, verbose=1, scoring="r2")
# grid_rf.fit(X_training, y_training)

# print("Best RandomForestRegressor Model: " + str(grid_rf.best_estimator_))
# print("Best Score: " + str(grid_rf.best_score_))

# %%
# rf = grid_rf.best_estimator_
# rf.fit(X_training, y_training)
# rf_pred = rf.predict(X_valid)
# r2_rf = r2_score(y_valid, rf_pred)
# rmse_rf = np.sqrt(mean_squared_error(y_valid, rf_pred))
# print("R^2 Score: " + str(r2_rf))
# print("RMSE Score: " + str(rmse_rf))

# %%
# scores_rf = cross_val_score(rf, X_training, y_training, cv=10, scoring="r2")
# print("Cross Validation Score: " + str(np.mean(scores_rf)))

# %% [markdown]
# # 3. 측정 및 결과

# %%
model_performances = pd.DataFrame({
    "Model" : ["Linear Regression", "Ridge", "Lasso"],
    "Best Score" : [grid_linreg.best_score_,  grid_ridge.best_score_, grid_lasso.best_score_],
    "R Squared" : [str(r2_lin)[0:5], str(r2_ridge)[0:5], str(r2_lasso)[0:5]],
    "RMSE" : [str(rmse_lin)[0:8], str(rmse_ridge)[0:8], str(rmse_lasso)[0:8]]
})

# "Model" : "Decision Tree Regressor", "Random Forest Regressor" 빠짐
# "Best Score" : grid_dtr.best_score_, grid_rf.best_score_
# "R Squared" : str(r2_dtr)[0:5], str(r2_rf)[0:5]
#  RMSE" : str(rmse_dtr)[0:8], str(rmse_rf)[0:8]

model_performances.round(4)

print("Sorted by Best Score:")
model_performances.sort_values(by="Best Score", ascending=False)
# Out:
# Sorted by Best Score:
#    Best Score              Model R Squared      RMSE
# 2    0.513831              Lasso     0.513  339946.9
# 0    0.513831  Linear Regression     0.513  339948.4
# 1    0.513821              Ridge     0.513  339904.7

# %%
print("Sorted by R Squared:")
model_performances.sort_values(by="R Squared", ascending=False)
# Out:
# Sorted by R Squared:
#    Best Score              Model R Squared      RMSE
# 0    0.513831  Linear Regression     0.513  339948.4
# 1    0.513821              Ridge     0.513  339904.7
# 2    0.513831              Lasso     0.513  339946.9

# %%
print("Sorted by RMSE:")
model_performances.sort_values(by="RMSE", ascending=True)
# Out:
# Sorted by RMSE:
#    Best Score              Model R Squared      RMSE
# 1    0.513821              Ridge     0.513  339904.7
# 2    0.513831              Lasso     0.513  339946.9
# 0    0.513831  Linear Regression     0.513  339948.4
